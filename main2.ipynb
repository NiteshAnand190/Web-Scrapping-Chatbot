# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from bs4 import BeautifulSoup
from google.generativeai import GenerativeModel
import google.generativeai as genai

class WebScraper:
    def __init__(self, url, api_key):
        """
        Initialize the Selenium WebDriver and configure the Gemini API client.
        :param url: URL of the webpage to scrape
        :param api_key: API key for accessing Gemini
        """
        # Set up the Chrome WebDriver
        self.data = []
        options = webdriver.ChromeOptions()
        service = Service(ChromeDriverManager().install())
        self.driver = webdriver.Chrome(service=service, options=options)
        
        # Open the specified URL
        self.driver.get(url)
        time.sleep(2)
        
        # Configure Gemini API client
        genai.configure(api_key=api_key)  # Use the provided API key
        self.gemini_model = GenerativeModel("gemini-pro")

    def teardown(self):
        """
        Quit the Selenium WebDriver.
        """
        self.driver.quit()

    def scrap_data(self):
        """
        Scrape the body HTML content from the webpage and extract plain text using BeautifulSoup.
        Also retrieves specific HTML content (e.g., from an H1 tag).
        """
        body_element = self.driver.find_element(By.TAG_NAME, "body")
        body_html_content = body_element.get_attribute("innerHTML")
        
        # Parse the HTML content with BeautifulSoup to extract plain text
        soup = BeautifulSoup(body_html_content, 'html.parser')
        plain_text = soup.get_text(separator=" ", strip=True)  # Get plain text from HTML
        
        print("*********************************", plain_text)  # Print the extracted text

        # Call Gemini function to get response
        self.get_gemini_response(plain_text)

    def scrap_all_link(self):
        anchor_elements = self.driver.find_elements(By.TAG_NAME, "a")

        for el in anchor_elements:
            try:
                curr_url = el.get_attribute("href")
                self.driver.get(curr_url)
                time.sleep(2)

                self.scrap_data()
            except:
                pass


    def get_gemini_response(self, text_content):
        """
        Send the text content to Gemini for analysis.
        :param text_content: The text content to send to Gemini
        """
        print(f"Sending the following text to Gemini:\n{text_content}")
        
        try:
            # Generate content using the Gemini API
            response = self.gemini_model.generate_content(
                f"Analyze the content of this webpage \n {text_content}"
            )
            print("Gemini Response:", response.text)  # Print the response
        except Exception as e:
            print(f"Error with Gemini API Call: {e}")

    def get_answer_for_prompt(self):
        while True:
            prompt = input("What do you want to ask? (type 'exit' to quit): ")
            if prompt.lower() == 'exit':
                print("Exiting question mode.")
                break
            response = self.get_gemini_response(prompt)
            print(response)

if __name__ == "__main__":
    api_key = "AIzaSyCcZdZkLCwyNNjqgRl7_e4iou6Ii6u4c4M"  # Replace with your actual API key
    scraper = WebScraper("https://botpenguin.com", api_key)  # Initialize the scraper with URL and API key
    scraper.scrap_all_link() # Perform the data scraping and analysis
    scraper.teardown()  # Close the Selenium WebDriver

    scraper.get_answer_for_prompt()
# Out:
# ********************************* Why BotPenguin Product Solutions Pricing Partners Resources Login Get Started FREE Integrations Experience 80+ world-class integrations. Key Features Take your business to the next level with our awesome key features. Live Chat Stay in the loop with your clientele 24*7! Unified Inbox Serve your customers across all platforms. Analytics Speedtrack your growth with our top-of-the-line analytics tools! Mobile App Make, monitor, & manage your AI chatbots with our mobile app. CHATBOT COMPARISONS BotPenguin vs. Manychat BotPenguin vs. Tidio BotPenguin vs. Tawk.to BotPenguin vs. Wati BotPenguin vs. Interakt BotPenguin vs. AiSensy BotPenguin vs. Landbot WHAT CAN IT DO? Marketing Automation Make marketing a boon from the automation gods! FB Automation Engage with your customers on a deeper level. WhatsApp Automation Get that nifty automation for WhatsApp too! Appointment Bookings No more delays, BotPenguin’s got you here! Customer Support Your customers are in for a treat with this automation. Lead Generation Gain more lead without any extra effort or expenses WHO CAN USE IT? Healthcare Give your patients world-class healthcare service! Education Make admissions and automate processes in a jiffy! E-commerce Create the best E-commerce service with ease! Real Estate Make Real Estate great again with BotPenguin! Consultants Boost up with our one-stop marketing solution! SaaS Take your SAAS game to the next level with BotPenguin! Tours & Travels Provide extraordinary tour and travel services with BotPenguin! Insurance Launch AI-driven Insurance Bot to Promote, Sell, & Manage Policies. WHERE CAN IT RUN? Instagram Chatbot Attract leads, boost sales, and chat 24/7 with Instagram Chatbots. WhatsApp Chatbot Start conversing like a real person with BotPenguin! Telegram Chatbot Cutting-edge features for you to grow your business on Telegram. Facebook Chatbot Do everything at once with BotPenguin on Facebook. Websites Chatbot BotPenguin grows your website and keeps your customers engaged. Wordpress Chatbot BotPenguin thrives on WordPress and makes it awesome. Microsoft Teams Chatbot Maximize your teams productivity with MS Teams Bot. Shopify Chatbot Boost your Shopify Business With BotPenguin’s AI-powered chatbot. WooCommerce Chatbot Sell effortlessly on your WooCommerce store with BotPenguin. Squarespace Chatbot Get the most out of Squarespace with BotPenguin CUSTOM DEVELOPMENT Whitelabel ChatGPT Apply your branding on ChatGPT, Launch your own AI platform ChatGPT Custom Plugins Integrate your service straight into ChatGPT Custom Chatbot Development Build enterprise-grade chatbots with the best ChatGPT Clone Add functionality and branding on ChatGPT HIRE DEVELOPERS Chatbot Developers Build Lighter, Faster, Smarter-Efficiently ChatGPT Developers Ride the GPT wave with trained surfers ChatGPT Consultants Advice that makes the difference in your AI journey PARTNER PROGRAMS Partners Home Join hands with us, and welcome growth White Label Partners Say hi to the best White Label chatbot platform ever WhatsApp White Label Partners Conquer the WhatsApp land with BotPenguin’s White Label Platform Instagram White Label Partners Capture Social Media Market with BotPenguin's White Label AI Platform! Affiliate Partners Earn more and keep your clients happier Implementation Partners As they say, a partner is worth trillions! PARTNER PRICING White Label Chatbot Pricing Our pricing for White label Chatbot Implementation Partnership Pricing Our pricing for Implementation Partnership OUR RESOURCES Blogs Read the latest blogs on chatbots, AI, automations & more Videos Watch tutorials, webinars, and demos to master our chatbots. Case Study Read how BotPenguin transformed business communication E-book Explore e-books written by experts for all your business needs! Help Docs Find detailed guides and tips for all your chatbot needs. Newsroom Explore how BotPenguin is making headlines in the chatbot industry. Community Support Join our v ...
# Sending the following text to Gemini:
# Why BotPenguin Product Solutions Pricing Partners Resources Login Get Started FREE Integrations Experience 80+ world-class integrations. Key Features Take your business to the next level with our awesome key features. Live Chat Stay in the loop with your clientele 24*7! Unified Inbox Serve your customers across all platforms. Analytics Speedtrack your growth with our top-of-the-line analytics tools! Mobile App Make, monitor, & manage your AI chatbots with our mobile app. CHATBOT COMPARISONS BotPenguin vs. Manychat BotPenguin vs. Tidio BotPenguin vs. Tawk.to BotPenguin vs. Wati BotPenguin vs. Interakt BotPenguin vs. AiSensy BotPenguin vs. Landbot WHAT CAN IT DO? Marketing Automation Make marketing a boon from the automation gods! FB Automation Engage with your customers on a deeper level. WhatsApp Automation Get that nifty automation for WhatsApp too! Appointment Bookings No more delays, BotPenguin’s got you here! Customer Support Your customers are in for a treat with this automation. Lead Generation Gain more lead without any extra effort or expenses WHO CAN USE IT? Healthcare Give your patients world-class healthcare service! Education Make admissions and automate processes in a jiffy! E-commerce Create the best E-commerce service with ease! Real Estate Make Real Estate great again with BotPenguin! Consultants Boost up with our one-stop marketing solution! SaaS Take your SAAS game to the next level with BotPenguin! Tours & Travels Provide extraordinary tour and travel services with BotPenguin! Insurance Launch AI-driven Insurance Bot to Promote, Sell, & Manage Policies. WHERE CAN IT RUN? Instagram Chatbot Attract leads, boost sales, and chat 24/7 with Instagram Chatbots. WhatsApp Chatbot Start conversing like a real person with BotPenguin! Telegram Chatbot Cutting-edge features for you to grow your business on Telegram. Facebook Chatbot Do everything at once with BotPenguin on Facebook. Websites Chatbot BotPenguin grows your website and keeps your customers engaged. Wordpress Chatbot BotPenguin thrives on WordPress and makes it awesome. Microsoft Teams Chatbot Maximize your teams productivity with MS Teams Bot. Shopify Chatbot Boost your Shopify Business With BotPenguin’s AI-powered chatbot. WooCommerce Chatbot Sell effortlessly on your WooCommerce store with BotPenguin. Squarespace Chatbot Get the most out of Squarespace with BotPenguin CUSTOM DEVELOPMENT Whitelabel ChatGPT Apply your branding on ChatGPT, Launch your own AI platform ChatGPT Custom Plugins Integrate your service straight into ChatGPT Custom Chatbot Development Build enterprise-grade chatbots with the best ChatGPT Clone Add functionality and branding on ChatGPT HIRE DEVELOPERS Chatbot Developers Build Lighter, Faster, Smarter-Efficiently ChatGPT Developers Ride the GPT wave with trained surfers ChatGPT Consultants Advice that makes the difference in your AI journey PARTNER PROGRAMS Partners Home Join hands with us, and welcome growth White Label Partners Say hi to the best White Label chatbot platform ever WhatsApp White Label Partners Conquer the WhatsApp land with BotPenguin’s White Label Platform Instagram White Label Partners Capture Social Media Market with BotPenguin's White Label AI Platform! Affiliate Partners Earn more and keep your clients happier Implementation Partners As they say, a partner is worth trillions! PARTNER PRICING White Label Chatbot Pricing Our pricing for White label Chatbot Implementation Partnership Pricing Our pricing for Implementation Partnership OUR RESOURCES Blogs Read the latest blogs on chatbots, AI, automations & more Videos Watch tutorials, webinars, and demos to master our chatbots. Case Study Read how BotPenguin transformed business communication E-book Explore e-books written by experts for all your business needs! Help Docs Find detailed guides and tips for all your chatbot needs. Newsroom Explore how BotPenguin is making headlines in the chatbot industry. Community Support Join our vibrant community to unlock exclusi ...
# Gemini Response: **Product Features:**
#
# * Omnichannel customer support
# * Marketing automation
# * Sales engagement
# * E-commerce functionality
# * Live chat integration
# * Unified inbox
# * Advanced analytics
# * 80+ native integrations
# * No-code chatbot builder
# * Multilingual chatbot
# * Custom AI personas
# * CRM and payment gateway integrations
#
# **Key Features:**
#
# * **Take your business to the next level with our awesome key features.**
# * **Stay in the loop with your clientele 24*7!**
# * **Serve your customers across all platforms.**
# * **Speedtrack your growth with our top-of-the-line analytics tools!**
# * **Make, monitor, & manage your AI chatbots with our mobile app.**
#
# **Use Cases:**
#
# * **Marketing Automation:** Automating marketing tasks to increase efficiency.
# * **FB Automation:** Engaging with customers on Facebook.
# * **WhatsApp Automation:** Automating WhatsApp communication.
# * **Appointment Bookings:** Facilitating appointment scheduling.
# * **Customer Support:** Providing customer support via chatbot.
# * **Lead Generation:** Generating leads with minimal effort.
#
# **Target Audience:**
#
# * Healthcare
# * Education
# * E-commerce
# * Real Estate
# * Consultants
# * SaaS
# * Tours & Travels
# * Insurance
#
# **Platform Compatibility:**
#
# * Instagram
# * WhatsApp
# * Telegram
# * Facebook
# * Websites
# * Wordpress
# * Microsoft Teams
# * Shopify
# * WooCommerce
# * Squarespace
#
# **Custom Development:**
#
# * Whitelabel ChatGPT
# * ChatGPT Custom Plugins
# * Custom Chatbot Development
# * ChatGPT Clone
# * Hire Developers
#
# **Partner Programs:**
#
# * White Label Partners
# * WhatsApp White Label Partners
# * Instagram White Label Partners
# * Affiliate Partners
# * Implementation Partners
#
# **Resources:**
#
# * Blogs
# * Videos
# * Case Studies
# * E-books
# * Help Docs
# * Newsroom
# * Community Support
#
# **Testimonials:**
#
# * G2
# * Capterra
# * Trustpilot
# * Good Firms
# * Crozdesk
#
# **Additional Features:**
#
# * 100% data security
# * Free forever plan
# * Multilingual support
# * Advanced AI capabilities
# * Integrations with CRMs, payment gateways, and other software
# What do you want to ask? (type 'exit' to quit): blogs
# Sending the following text to Gemini:
# blogs
# Gemini Response: **Webpage Content Analysis**
#
# **URL:** [Provide the URL of the webpage to be analyzed]
#
# **Title:** [Enter the title of the webpage]
#
# **Headings:**
#
# * **H1:** [Main heading of the webpage]
# * **H2:** [Subheadings within the main heading]
# * **H3:** [Subheadings within the subheadings]
#
# **Body Content:**
#
# * **Length:** [Estimated number of words or characters in the body content]
# * **Topics:** [Main themes or subjects covered in the content]
# * **Keywords:** [Important words or phrases that describe the content]
# * **Call to Action:** [Specific instructions or requests made to readers]
# * **Tone:** [Overall style or mood of the writing (e.g., informative, persuasive, entertaining)]
#
# **Images and Multimedia:**
#
# * **Image count:** [Number of images or other visual elements on the page]
# * **Type of images:** [Descriptions of the images, such as photos, illustrations, or graphics]
# * **Alt text:** [Alternative descriptions of images for accessibility purposes]
# * **Videos or audio:** [Presence of any embedded videos or audio content]
#
# **Links:**
#
# * **Internal links:** [Links to other pages within the same website]
# * **External links:** [Links to websites outside the domain]
# * **Broken links:** [Any links that are no longer valid]
#
# **Navigation:**
#
# * **Menu structure:** [Organization and hierarchy of navigation options]
# * **Breadcrumbs:** [Indicators of current location within the website]
# * **Footer:** [Additional links or information at the bottom of the page]
#
# **Meta Tags:**
#
# * **Title tag:** [Descriptive title displayed in search engine results]
# * **Meta description:** [Brief summary of the webpage's content]
# * **Keywords tag:** [List of words or phrases used for search engine optimization]
#
# **Technical Aspects:**
#
# * **Page speed:** [How quickly the page loads for users]
# * **Mobile responsiveness:** [Adaptability of the page to different screen sizes]
# * **Security:** [Presence of an HTTPS protocol for secure browsing]
#
# **Target Audience:**
#
# * **Demographic:** [Age, gender, education level, etc. of the intended readers]
# * **Interests:** [Specific topics or areas of knowledge that the audience is likely to be interested in]
# * **Needs:** [Problems or questions that the webpage aims to address]
#
# **Overall Objective:**
#
# * **Informative:** [Providing factual information or knowledge]
# * **Persuasive:** [Convincing readers to take a certain action or adopt a particular viewpoint]
# * **Entertaining:** [Amusing or engaging readers with stories or humor]
# * **Transactional:** [Facilitating purchases or other business transactions]
# * **Other:** [Specify any other objectives of the webpage]
# None
# What do you want to ask? (type 'exit' to quit): what is the pricing of botpenguine
# Sending the following text to Gemini:
# what is the pricing of botpenguine
# Gemini Response: The provided webpage does not contain any information on the pricing of botpenguine. Therefore, I cannot analyze the content of the webpage for the pricing of botpenguine.
# None
# What do you want to ask? (type 'exit' to quit): why botpenguine
# Sending the following text to Gemini:
# why botpenguine
# Gemini Response: **URL:** https://www.botpenguine.com/
#
# **Content Analysis:**
#
# **About:**
# Bot Penguin is a platform that offers AI-powered chatbots for businesses to automate customer interactions. It allows users to create chatbots without coding skills and provides various chatbot templates and features.
#
# **Key Features:**
#
# * **No-code chatbot creation:** Users can create chatbots without any programming knowledge.
# * **Chatbot templates:** The platform offers a library of pre-built chatbot templates for different industries and use cases.
# * **Conversation analytics:** Businesses can track chatbot performance and gain insights into customer interactions.
# * **Live chat support:** AI-powered chatbots provide 24/7 live chat support to customers.
# * **Multi-channel integration:** Chatbots can be integrated with popular messaging platforms like WhatsApp, Facebook Messenger, and Telegram.
#
# **Benefits for Businesses:**
#
# * **Improved customer service:** Chatbots handle customer inquiries and provide support around the clock.
# * **Cost reduction:** Automation reduces the need for human customer service agents, saving on expenses.
# * **Increased sales:** Chatbots can engage with potential customers, recommend products, and facilitate transactions.
# * **Enhanced customer experience:** Chatbots provide a convenient and personalized experience for customers.
#
# **Target Audience:**
#
# * Small and medium-sized businesses
# * Businesses looking to automate customer interactions
# * Companies seeking to improve customer service and sales
# * Individuals interested in creating chatbots
#
# **Content Quality:**
#
# The website content is well-written and informative. It clearly explains the benefits and features of the platform. The chatbot templates and live chat support are unique selling points that are highlighted.
#
# **Trustworthiness:**
#
# The website appears trustworthy. It has a secure SSL certificate and provides clear contact information. There are also testimonials from satisfied customers.
#
# **Overall Impression:**
#
# Bot Penguin is a user-friendly platform that offers a range of features to help businesses automate customer interactions and improve their customer service. The no-code chatbot creation and pre-built templates make it accessible to businesses of all sizes. The focus on customer service and cost reduction aligns with the needs of many businesses.
# None
# What do you want to ask? (type 'exit' to quit): custom development of botpenguine
# Sending the following text to Gemini:
# custom development of botpenguine
# Gemini Response: The webpage you provided focuses on the custom development of BotPenguine, which is a turnkey AI-powered chatbot solution. The content is well-organized and provides a comprehensive overview of the platform's capabilities, benefits, and industries it serves.
#
# **Key Features and Benefits:**
#
# * **AI-powered:** BotPenguine utilizes advanced AI technologies, including natural language processing (NLP) and machine learning (ML), to provide human-like interactions.
# * **Turnkey solution:** The platform is fully managed, requiring minimal setup and maintenance.
# * **Customization:** Businesses can tailor BotPenguine to their specific needs and brand identity.
# * **Omnichannel support:** BotPenguine can be integrated into multiple communication channels, such as websites, messaging apps, and social media.
# * **Data analytics:** The platform provides real-time data and analytics to track chatbot performance and improve customer experiences.
# * **Improved customer service:** BotPenguine enables businesses to automate customer interactions, resolve queries quickly, and provide 24/7 support.
# * **Increased sales and revenue:** The chatbot can assist customers with product recommendations, upselling, and cross-selling.
# * **Reduced costs:** BotPenguine reduces the need for manual customer support, freeing up human agents for more complex tasks.
#
# **Industries Served:**
#
# BotPenguine is suitable for a wide range of industries, including:
#
# * **E-commerce:** Enhancing customer support, product recommendations, and order tracking.
# * **Healthcare:** Providing medical information, scheduling appointments, and answering patient questions.
# * **Education:** Offering course information, homework assistance, and student support.
# * **Financial services:** Assisting with account inquiries, transaction processing, and financial advice.
# * **Travel and hospitality:** Booking flights, arranging accommodations, and providing travel information.
#
# **Competitive Advantage:**
#
# BotPenguine differentiates itself from competitors by offering a comprehensive package of features, including:
#
# * Advanced AI capabilities for personalized interactions
# * End-to-end management and support
# * Customizable interface and branding options
# * Integration with existing systems
# * Robust data analytics and reporting
#
# **Conclusion:**
#
# The webpage effectively showcases the value proposition of BotPenguine as a custom AI-powered chatbot solution. By leveraging advanced technology, providing turnkey services, and offering industry-specific solutions, BotPenguine enables businesses to enhance customer experiences, streamline operations, and drive growth.
# None
# What do you want to ask? (type 'exit' to quit): who can use botpenguine ai
# Sending the following text to Gemini:
# who can use botpenguine ai
# Gemini Response: **Who Can Use BotPenguin AI?**
#
# **Individuals:**
#
# * **Freelancers and Solopreneurs:** Automate tasks, streamline workflows, and save time on repetitive tasks.
# * **Students and Researchers:** Access expert knowledge, generate creative content, and improve assignment quality.
# * **Content Creators:** Create engaging and informative content for various platforms, including social media, blogs, and websites.
# * **Personal Assistants:** Manage schedules, appointments, emails, and administrative tasks efficiently.
# * **Anyone with a Need to Automate:** Automate any task or process that requires repetition, consistency, or data extraction.
#
# **Businesses:**
#
# * **Small Businesses:** Reduce operational costs, improve productivity, and enhance customer service.
# * **Startups:** Quickly create high-quality content, develop data-driven insights, and automate marketing tasks.
# * **Enterprise Organizations:** Streamline operations, automate complex processes, and gain valuable insights from data analysis.
#
# **Specific Industries:**
#
# * **Healthcare:** Automate appointment scheduling, medical record retrieval, and provide patient care information.
# * **Education:** Personalize learning experiences, assist with language learning, and provide feedback on assignments.
# * **E-commerce:** Enhance product descriptions, optimize pricing, and improve customer service.
# * **Finance:** Automate financial data analysis, generate investment recommendations, and provide risk assessment.
# * **Manufacturing:** Optimize production processes, predict machine maintenance, and improve quality control.
#
# **Technical Considerations:**
#
# * **No Coding Required:** BotPenguin AI requires no coding knowledge or technical expertise.
# * **Cloud-Based Platform:** Access BotPenguin AI from anywhere with an internet connection.
# * **API Integration:** Integrates with other tools and applications to automate workflows.
# * **Data Security:** All data processed by BotPenguin AI is handled securely and confidentially.
# None
